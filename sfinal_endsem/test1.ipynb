# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("data.csv")

# %% [markdown]
# # first 5

# %%
df.head()
# Out:
#   company body-style  wheelbase  length   hp  avg-mileage    price
# 0  jaguar      sedan      113.0   119.6  176           15  32250.0
# 1  jaguar      sedan      113.0   119.6  176           15  35550.0
# 2  jaguar      sedan      102.0   191.7  262           13  36000.0
# 3   mazda  hatchback       93.1   159.1   68           30   5195.0
# 4   mazda  hatchback       93.1   159.1   68           31   6095.0

# %% [markdown]
# # last 5

# %%
df.tail()
# Out:
#     company   body-style  wheelbase  length   hp  avg-mileage    price
# 18   nissan        sedan      100.4   184.6   69           31   7349.0
# 19   nissan        wagon       89.5   168.9   69           31  13499.0
# 20  porsche        sedan       89.5   186.9  152           19  34028.0
# 21  porsche  convertible       94.5   175.7  207           17  37028.0
# 22  porsche    hatchback       98.4   175.7  207           17      NaN

# %%
df1=df[["company"," price"]]
df1.head()
# Out:
#   company    price
# 0  jaguar  32250.0
# 1  jaguar  35550.0
# 2  jaguar  36000.0
# 3   mazda   5195.0
# 4   mazda   6095.0

# %% [markdown]
# # after cleaning

# %%
df=df.dropna()
df.tail()
# Out:
#     company   body-style  wheelbase  length   hp  avg-mileage    price
# 17   nissan        sedan      94.45   170.2   69           31   6649.0
# 18   nissan        sedan     100.40   184.6   69           31   7349.0
# 19   nissan        wagon      89.50   168.9   69           31  13499.0
# 20  porsche        sedan      89.50   186.9  152           19  34028.0
# 21  porsche  convertible      94.50   175.7  207           17  37028.0

# %% [markdown]
# # count car per company

# %%
df2=df[["company"," price"]]
df1=df2.groupby("company")
df1.count()
# Out:
#                 price
# company
# jaguar              3
# mazda               5
# mercedes-benz       4
# mitsubishi          4
# nissan              4
# porsche             2

# %% [markdown]
# # print all toyoto cars

# %%
df=pd.read_csv("data.csv")
df1=df[df.company=="jaguar"]
df1
# Out:
#   company body-style  wheelbase  length   hp  avg-mileage    price
# 0  jaguar      sedan      113.0   119.6  176           15  32250.0
# 1  jaguar      sedan      113.0   119.6  176           15  35550.0
# 2  jaguar      sedan      102.0   191.7  262           13  36000.0

# %% [markdown]
# # count car per company

# %%
df2=df[["company"," price"]]
df1=df2.groupby("company")
df1.count()
# Out:
#                 price
# company
# jaguar              3
# mazda               5
# mercedes-benz       4
# mitsubishi          4
# nissan              4
# porsche             2

# %%
sns.boxplot(data=df,x="company",y="hp")
# Out:
# <Axes: xlabel='company', ylabel='hp'>

# %%
sns.FacetGrid(df,hue="company").map(plt.scatter,"hp","length").add_legend()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.hist("hp")
plt.title("histogram")
# Out:
# Text(0.5, 1.0, 'histogram')

# %%
df.describe()
# Out:
#         wheelbase      length          hp  avg-mileage         price
# count   22.000000   22.000000   22.000000    22.000000     22.000000
# mean   100.011364  170.236364  115.363636    24.863636  19301.909091
# std      9.159070   21.838488   58.970166     8.697539  14181.441964
# min     89.500000  119.600000   55.000000    13.000000   5195.000000
# 25%     93.400000  159.100000   68.250000    17.000000   6843.500000
# 50%     94.900000  169.600000   88.000000    25.000000  12672.000000
# 75%    108.725000  186.325000  170.000000    31.000000  33583.500000
# max    120.900000  208.100000  262.000000    45.000000  45400.000000

# %% [markdown]
# # MEAN OF THE HORSE POWER

# %%
df2=df[["company","hp"]]
df1=df2.groupby("company")
df1.mean()
# Out:
#                        hp
# company
# jaguar         204.666667
# mazda           75.400000
# mercedes-benz  153.500000
# mitsubishi      78.000000
# nissan          65.500000
# porsche        179.500000

# %% [markdown]
# # MEDIAN OF THE HORSE POWER

# %%
df2=df[["company","hp"]]
df1=df2.groupby("company")
df1.median()
# Out:
#                   hp
# company
# jaguar         176.0
# mazda           68.0
# mercedes-benz  153.5
# mitsubishi      78.0
# nissan          69.0
# porsche        179.5

# %% [markdown]
# # mode of horse power

# %%
from scipy import stats
x=stats.mode(df["hp"])
x[0]
# Out:
# 68

# %% [markdown]
# # AVG MILEAGE OF EACH CAR MAKING COMPANY

# %%
df2=df[["company","avg-mileage"]]
df1=df2.groupby("company")
df1.mean()
# Out:
#                avg-mileage
# company
# jaguar           14.333333
# mazda            28.000000
# mercedes-benz    18.000000
# mitsubishi       29.500000
# nissan           34.500000
# porsche          18.000000

# %% [markdown]
# # COUNT TOTAL CAR PER COMPANY

# %%
df2=df[["company"," price"]]
df1=df2.groupby("company")
df1.count()
# Out:
#                 price
# company
# jaguar              3
# mazda               5
# mercedes-benz       4
# mitsubishi          4
# nissan              4
# porsche             2

# %% [markdown]
# # ALL NISSAN CARS

# %%
df1=df[df.company=="nissan"]
df1.head()
# Out:
#   company body-style  wheelbase  length   hp  avg-mileage    price
# 0  nissan      sedan      113.0   119.6  176           15  32250.0
# 1  nissan      sedan      113.0   119.6  176           15  35550.0
# 2  nissan      sedan      102.0   191.7  262           13  36000.0
# 3  nissan  hatchback       93.1   159.1   68           30   5195.0
# 4  nissan  hatchback       93.1   159.1   68           31   6095.0

# %% [markdown]
# # EACH COMPANY CAR MAX PRICE

# %%
df1=df[["company"," price"]]
df2=df1.groupby("company")
df2.max()
# Out:
#                  price
# company
# jaguar         36000.0
# mazda          18344.0
# mercedes-benz  45400.0
# mitsubishi      8189.0
# nissan         13499.0
# porsche        37028.0

# %% [markdown]
# # covarience

# %%
df1=df[["company","avg-mileage"," price"]]
df2=df1.groupby("company")
df2.cov()
# Out:
#                             avg-mileage         price
# company
# jaguar        avg-mileage      1.333333 -1.400000e+03
#                price       -1400.000000  4.192500e+06
# mazda         avg-mileage     38.000000 -6.550750e+03
#                price       -6550.750000  3.025991e+07
# mercedes-benz avg-mileage     21.333333 -4.341333e+04
#                price      -43413.333333  9.284314e+07
# mitsubishi    avg-mileage     33.000000 -6.200000e+03
#                price       -6200.000000  1.426667e+06
# nissan        avg-mileage     49.000000 -7.233333e+03
#                price       -7233.333333  1.053833e+07
# porsche       avg-mileage      1.333333 -3.000000e+03
#                price       -3000.000000  4.500000e+06

# %% [markdown]
# # CORRELATION

# %%
df1=df[["company","avg-mileage"," price"]]
df2=df1.groupby("company")
df2.corr()
# Out:
#                            avg-mileage     price
# company
# jaguar        avg-mileage     1.000000 -0.592137
#                price         -0.592137  1.000000
# mazda         avg-mileage     1.000000 -0.193181
#                price         -0.193181  1.000000
# mercedes-benz avg-mileage     1.000000 -0.975481
#                price         -0.975481  1.000000
# mitsubishi    avg-mileage     1.000000 -0.903594
#                price         -0.903594  1.000000
# nissan        avg-mileage     1.000000 -0.318313
#                price         -0.318313  1.000000
# porsche       avg-mileage     1.000000 -1.000000
#                price         -1.000000  1.000000

# %% [markdown]
# # MOST EXPENSIVE CAR COMPANY NAME

# %%
df1=df[[" price"]]
m=float(df1.max())
df3=df[["company"," price"]]
df2=df3[df3[" price"]==m]
df2
# Out:
# C:\Users\assess1\AppData\Local\Temp\ipykernel_7708\528955123.py:2: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   m=float(df1.max())
#           company    price
# 11  mercedes-benz  45400.0

# %%
df1=df[[" price"]]
m=df1.max()
m
# Out:
#  price    45400.0
# dtype: float64

# %%
from scipy import stats
x=stats.mode(df["hp"])
x
# Out:
# ModeResult(mode=68, count=5)

# %%
df1=(by=df[" price"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 df1=arrange(by=df[" price"])
#
# NameError: name 'arrange' is not defined

# %% [markdown]
# # sort by price

# %%
df1=df.sort_values(" price")
df1
# Out:
#           company   body-style  wheelbase  length   hp  avg-mileage    price
# 3           mazda    hatchback      93.10   159.1   68           30   5195.0
# 12     mitsubishi    hatchback      93.70   157.3   68           37   5389.0
# 4           mazda    hatchback      93.10   159.1   68           31   6095.0
# 13     mitsubishi    hatchback      93.70   157.3   68           31   6189.0
# 17         nissan        sedan      94.45   170.2   69           31   6649.0
# 5           mazda    hatchback      93.10   159.1   68           31   6795.0
# 14     mitsubishi        sedan      96.30   172.4   88           25   6989.0
# 16         nissan        sedan      94.50   165.3   55           45   7099.0
# 18         nissan        sedan     100.40   184.6   69           31   7349.0
# 15     mitsubishi        sedan      93.30   165.3   88           25   8189.0
# 6           mazda    hatchback      95.30   169.0  101           17  11845.0
# ...
